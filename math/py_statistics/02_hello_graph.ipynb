# %% [markdown]
# # Linear Regression
# The term `regression` is used when you try to find the relationship between variables.
#
# `Linear regression` uses the relationship between the data-points to draw a straight line through all them.
#
# This line can be used to predict future values.

# %%
 import matplotlib.pyplot as plt

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
from scipy import stats

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
def myfunc(x):
  return slope * x + intercept

# %%
mymodel = list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# # R-Squared
# Relationship between the values of the x-axis and the values of the y-axis is, if there are no relationship the linear regression can not be used to predict anything.
#
# ** The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related.**
#
# ![](../../images/2020-07-22-20-49-17.png)
#
# - SSres: Sum of squared regression
# - SStot: Sum of Squared total
# - yi : actual value
# - yi_cap: predicted value
# - yi_bar: mean of actual value

# %%
print(r)
# Out:
# -0.7585915243761551

# %% [markdown]
# # Predict Future Values

# %%
speed = myfunc(10)
print(speed)
# Out:
# 85.59308314937454
